# %%
# create dataframe from dict
#method 1- get items of dict(in this u cannot give column name,default(0,1,2,3))
pd.DataFrame.from_dict(a.items())
#method 2- convert items of dict to list(in this columns name can be given) 
pd.DataFrame(list(a.items()),columns=['words','count'])

# %%
# join list as string
str1 = ' '
text = str1.join(words)

# %%
# create dataframe using reset index
df['user'].value_counts().reset_index()

# %%
import pandas as pd

# %% [markdown]
# # read csv file

# %%
df = pd.read_csv("C:\\Users\\withu\\Documents\\Machine Learning\\EDA\\hotel_bookings.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # View Data
# - df.head(no of rows-default=5), top 5 data
# - df.tail(no of rows-default=5), bottom 5 data
# - df.sample(no of rows,deault=1), random rows data

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.sample()
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 80006  City Hotel            1         25               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 80006           November                        48                         27
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 80006                        2                     5       2  ...
#
#        deposit_type  agent company days_in_waiting_list customer_type   adr  \
# 80006    No Deposit    9.0     NaN                    0      Contract  87.0
#
#        required_car_parking_spaces  total_of_special_requests  \
# 80006                            0                          0
#
#        reservation_status reservation_status_date
# 80006            Canceled              2015-11-09
#
# [1 rows x 32 columns]

# %% [markdown]
# # How big is data

# %%
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# # Preview of columns and datatypes
# 1. info()
# - Column  |                        Non-Null |Count |  Dtype
# - in pandas Object datatype is same as string
# - dtypes: float64(4), int64(16), object(12)
# - memory usage: 29.1+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# # Describe Numerical Column
# - gives mathematical values
# - count,mean,std,min,25%,50%,75%,max

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# # Fetch Columns

# %%
# get all columns name
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# retrieve one column from the dataframe by name, this returns a series(without columns name)
df['hotel']
# Out:
# 0         Resort Hotel
# 1         Resort Hotel
# 2         Resort Hotel
# 3         Resort Hotel
# 4         Resort Hotel
#               ...
# 119385      City Hotel
# 119386      City Hotel
# 119387      City Hotel
# 119388      City Hotel
# 119389      City Hotel
# Name: hotel, Length: 119390, dtype: object

# %%
# retrieve two column from dataframe by name....and same for more then two, this retruns dataframe
df[['hotel','arrival_date_year']]
# Out:
#                hotel  arrival_date_year
# 0       Resort Hotel               2015
# 1       Resort Hotel               2015
# 2       Resort Hotel               2015
# 3       Resort Hotel               2015
# 4       Resort Hotel               2015
# ...              ...                ...
# 119385    City Hotel               2017
# 119386    City Hotel               2017
# 119387    City Hotel               2017
# 119388    City Hotel               2017
# 119389    City Hotel               2017
#
# [119390 rows x 2 columns]

# %%
# fetching columns using iloc[rows_from:rows_to,[columns]]
df.iloc[:,[0,1,4,5]]
# Out:
#                hotel  is_canceled arrival_date_month  arrival_date_week_number
# 0       Resort Hotel            0               July                        27
# 1       Resort Hotel            0               July                        27
# 2       Resort Hotel            0               July                        27
# 3       Resort Hotel            0               July                        27
# 4       Resort Hotel            0               July                        27
# ...              ...          ...                ...                       ...
# 119385    City Hotel            0             August                        35
# 119386    City Hotel            0             August                        35
# 119387    City Hotel            0             August                        35
# 119388    City Hotel            0             August                        35
# 119389    City Hotel            0             August                        35
#
# ...

# %% [markdown]
# # fetch rows

# %% [markdown]
# # 1.iloc()

# %%
# fetching first row(index will be columns name, values of row 0), same for other one row
df.iloc[0]
# Out:
# hotel                             Resort Hotel
# is_canceled                                  0
# lead_time                                  342
# arrival_date_year                         2015
# arrival_date_month                        July
# arrival_date_week_number                    27
# arrival_date_day_of_month                    1
# stays_in_weekend_nights                      0
# stays_in_week_nights                         0
# adults                                       2
# children                                   0.0
# babies                                       0
# meal                                        BB
# country                                    PRT
# market_segment                          Direct
# distribution_channel                    Direct
# is_repeated_guest                            0
# previous_cancellations                       0
# previous_bookings_not_canceled               0
# reserved_room_type                           C
# ...

# %%
# fetching more than one rows, it returns dataframe [from:to]
df.iloc[0:5]
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# fetching 0 to 10 rows with skipping every one rows, see indexing[from:to:skip no]
df.iloc[0:10:3]
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 3  Resort Hotel            0         13               2015               July
# 6  Resort Hotel            0          0               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 3                        27                          1
# 6                        27                          1
# 9                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# ...

# %%
# fetching by index no
df.iloc[[1,5,6,9]]
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 1  Resort Hotel            0        737               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 1                        27                          1
# 5                        27                          1
# 6                        27                          1
# 9                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 1                        0                     0       2  ...    No Deposit
# 5                        0                     2       2  ...    No Deposit
# ...

# %%
# fetching columns using iloc[rows_from:rows_to,[column1,column2]]....known as fancy indexing
df.iloc[:,[0,1,4,5]]
# Out:
#                hotel  is_canceled arrival_date_month  arrival_date_week_number
# 0       Resort Hotel            0               July                        27
# 1       Resort Hotel            0               July                        27
# 2       Resort Hotel            0               July                        27
# 3       Resort Hotel            0               July                        27
# 4       Resort Hotel            0               July                        27
# ...              ...          ...                ...                       ...
# 119385    City Hotel            0             August                        35
# 119386    City Hotel            0             August                        35
# 119387    City Hotel            0             August                        35
# 119388    City Hotel            0             August                        35
# 119389    City Hotel            0             August                        35
#
# ...

# %% [markdown]
# # fetching rows based on candition
# - known as masking

# %%
# fetching data for specific value in column, returns bool series(true/false)...known as masking
df['arrival_date_month']=='August'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385     True
# 119386     True
# 119387     True
# 119388     True
# 119389     True
# Name: arrival_date_month, Length: 119390, dtype: bool

# %%
mask = df['arrival_date_month']=='August'

# %%
# only get the data for which is TRUE
df[mask]
# same:- df[df['hotel']=='Resort Hotel']
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 842     Resort Hotel            0        129               2015
# 843     Resort Hotel            1         84               2015
# 844     Resort Hotel            1         84               2015
# 845     Resort Hotel            1         89               2015
# 846     Resort Hotel            1         10               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 842                August                        31
# 843                August                        31
# ...

# %%
df[mask].shape
# Out:
# (13877, 32)

# %%
df[mask].shape[0]
# Out:
# 13877

# %%
def get_month_count(month):
    mask = df['arrival_date_month']==month
    return df[mask].shape[0]

# %%
get_month_count('June')
# Out:
# 10939

# %%
get_month_count('December')
# Out:
# 6780

# %% [markdown]
# # two conditions

# %%
mask1 = df['arrival_date_month']=='August'
mask2 = df['arrival_date_year'] > 2016

# AND condition(both true)
df[mask1 & mask2]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 13115   Resort Hotel            1        122               2017
# 13116   Resort Hotel            1         78               2017
# 13117   Resort Hotel            1         67               2017
# 13118   Resort Hotel            1         69               2017
# 13119   Resort Hotel            1        198               2017
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 13115              August                        31
# 13116              August                        31
# ...

# %%
# AND condition(any one true)
df[mask1 | mask2]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 842     Resort Hotel            0        129               2015
# 843     Resort Hotel            1         84               2015
# 844     Resort Hotel            1         84               2015
# 845     Resort Hotel            1         89               2015
# 846     Resort Hotel            1         10               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 842                August                        31
# 843                August                        31
# ...

# %%
df[mask1 | mask2].shape
# Out:
# (49639, 32)

# %% [markdown]
# # value counts
# - frequency count data
# - used for categorical caolumns
# - returns series (index as category name)

# %%
df['hotel'].value_counts()
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
df['hotel'].nunique()
# Out:
# 2

# %% [markdown]
# # pandas plot function
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html
# - The kind of plot to produce:
# - ‘line’ : line plot (default)
# - ‘bar’ : vertical bar plot
# - ‘barh’ : horizontal bar plot
# - ‘hist’ : histogram
# - ‘box’ : boxplot
# - ‘kde’ : Kernel Density Estimation plot
# - ‘density’ : same as ‘kde’
# - ‘area’ : area plot
# - ‘pie’ : pie plot
# - ‘scatter’ : scatter plot (DataFrame only)
# - ‘hexbin’ : hexbin plot (DataFrame only)

# %%
# import matplotlib.pyplot as plt # use this is if not plot
df['hotel'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['arrival_date_month'].value_counts().head(3).plot(kind='pie',autopct='%.1f%%')
# Out:
# <AxesSubplot:ylabel='arrival_date_month'>

# %% [markdown]
# # Histogram
# - work same as bar chart(used for categorical)
# - hist plot create bins or interval between numerical data then represent same as bar, for ease of understanding continuous data

# %%
df['lead_time'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Series
# - single row data

# %%
type(df['hotel'])
# Out:
# pandas.core.series.Series

# %%
type(df['hotel'].value_counts())
# Out:
# pandas.core.series.Series

# %%
df['hotel'].value_counts() # left side data known as index(unique), right side value(can be repeate)
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
myseries = df['hotel'].value_counts()

# %%
myseries.index # == df['hotel'].value_counts().index
# Out:
# Index(['City Hotel', 'Resort Hotel'], dtype='object')

# %%
myseries.values # == df['hotel'].value_counts().values
# Out:
# array([79330, 40060], dtype=int64)

# %% [markdown]
# ## head/tail on series data

# %%
# df['arrival_date_month'].value_counts().head()
df['arrival_date_month'].value_counts().tail()
# Out:
# March       9794
# February    8068
# November    6794
# December    6780
# January     5929
# Name: arrival_date_month, dtype: int64

# %%
# extracting for Nov month only
df['arrival_date_month'].value_counts()['November']
# Out:
# 6794

# %% [markdown]
# # Adding two series data
# - let suppose we have two teams team1 and team2, now let CSK played as Team1 in 50 matches and played as Team2 in 100 matched, now we want to know the total matches played by CSK
# - see the below snapshots

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - count_values for team1 as all are unique index
# ![image-3.png](attachment:image-3.png)
# - count_values for team2 as all are unique index and same as team1
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - adding both, now we get the total matches played by all teams(same other maths can be applied)
# ![image.png](attachment:image.png)

# %% [markdown]
# # Sort Values
# - works both on Series and Dataframe

# %% [markdown]
# - sorting above results, by default ascending
# ![image.png](attachment:image.png)

# %% [markdown]
# - by descending
# ![image-2.png](attachment:image-2.png)

# %%
df.sort_values('hotel') # default: ascendong
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 59694    City Hotel            1        166               2016
# 79600    City Hotel            0          9               2015
# 79599    City Hotel            0         28               2015
# 79598    City Hotel            0         28               2015
# 79597    City Hotel            0        296               2015
# ...             ...          ...        ...                ...
# 26705  Resort Hotel            0         53               2016
# 26704  Resort Hotel            0         14               2016
# 26703  Resort Hotel            0        174               2016
# 26710  Resort Hotel            0          0               2016
# 0      Resort Hotel            0        342               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 59694           November                        45                          1
# ...

# %%
df.sort_values('hotel', ascending=False) # descending
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 26711   Resort Hotel            0          3               2016
# 26704   Resort Hotel            0         14               2016
# 26705   Resort Hotel            0         53               2016
# 26706   Resort Hotel            0         53               2016
# ...              ...          ...        ...                ...
# 66501     City Hotel            1        130               2017
# 66500     City Hotel            1        130               2017
# 66499     City Hotel            1        130               2017
# 66498     City Hotel            1        130               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 26711              August                        33
# ...

# %% [markdown]
# # inplace
#
# - for permanent changes in data
# - inplace=True (change to original data, df)
# - inplace= False (change changes for sort time)
# - be carefull while applying this, althought it will not impact on original data file like csv,excel

# %%
df.sort_values('is_canceled', ascending=False)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 59695     City Hotel            1        166               2016
# 61317     City Hotel            1        113               2016
# 61315     City Hotel            1         35               2016
# 61314     City Hotel            1         35               2016
# 61313     City Hotel            1         36               2016
# ...              ...          ...        ...                ...
# 36507   Resort Hotel            0        118               2017
# 36506   Resort Hotel            0        104               2017
# 36505   Resort Hotel            0         97               2017
# 36504   Resort Hotel            0        147               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 59695            November                        45
# 61317            December                        50
# ...

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# df.sort_values('is_canceled', ascending=False,inplace=True)

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# # Sort by multiple columns

# %%
df.sort_values(['arrival_date_year','arrival_date_month'])
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 842     Resort Hotel            0        129               2015
# 843     Resort Hotel            1         84               2015
# 844     Resort Hotel            1         84               2015
# 845     Resort Hotel            1         89               2015
# 846     Resort Hotel            1         10               2015
# ...              ...          ...        ...                ...
# 113282    City Hotel            0        129               2017
# 113427    City Hotel            0         24               2017
# 113442    City Hotel            0          2               2017
# 113447    City Hotel            0         38               2017
# 113501    City Hotel            0         38               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 842                August                        31
# 843                August                        31
# ...

# %%
df.sort_values(['arrival_date_year','arrival_date_month'],ascending=['True','False'])
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 842     Resort Hotel            0        129               2015
# 843     Resort Hotel            1         84               2015
# 844     Resort Hotel            1         84               2015
# 845     Resort Hotel            1         89               2015
# 846     Resort Hotel            1         10               2015
# ...              ...          ...        ...                ...
# 113282    City Hotel            0        129               2017
# 113427    City Hotel            0         24               2017
# 113442    City Hotel            0          2               2017
# 113447    City Hotel            0         38               2017
# 113501    City Hotel            0         38               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 842                August                        31
# 843                August                        31
# ...

# %%
df[df['arrival_date_year']==2015]['arrival_date_month'].value_counts()
# Out:
# September    5114
# October      4957
# August       3889
# December     2920
# July         2776
# November     2340
# Name: arrival_date_month, dtype: int64

# %% [markdown]
# # Drop Dupliated
# - subset=[columns name in list, one or multiple]
# - keep : {'first', 'last', False}, default 'first'
#     Determines which duplicates (if any) to keep.
#     - ``first`` : Drop duplicates except for the first occurrence.
#     - ``last`` : Drop duplicates except for the last occurrence.
#     - False : Drop all duplicates.
# - inplace : bool, default False
#     Whether to drop duplicates in place or to return a copy.
# - ignore_index : bool, default False
#     If True, the resulting axis will be labeled 0, 1, …, n - 1.

# %%
df.drop_duplicates(subset=['arrival_date_month'])
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 0     Resort Hotel            0        342               2015
# 842   Resort Hotel            0        129               2015
# 1485  Resort Hotel            1         38               2015
# 2087  Resort Hotel            0          0               2015
# 2835  Resort Hotel            1         33               2015
# 3271  Resort Hotel            0         20               2015
# 3738  Resort Hotel            0        109               2016
# 3864  Resort Hotel            1          3               2016
# 4275  Resort Hotel            1         15               2016
# 4803  Resort Hotel            1         31               2016
# 5521  Resort Hotel            1         36               2016
# 6275  Resort Hotel            1          7               2016
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                  July                        27                          1
# ...

# %%
print(df.shape)
print("Before droping duplicates vs after droping duplicates")
df.drop_duplicates(subset=['arrival_date_month']).shape
# Out:
# (119390, 32)
# Before droping duplicates vs after droping duplicates
# (12, 32)

# %% [markdown]
# - means only first occurence will be keep and rest will me dropped

# %%
df.drop_duplicates(subset=['arrival_date_month','is_canceled']).shape
# Out:
# (24, 32)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Groupby

# %%
df2 = pd.read_csv("C:\\Users\\withu\\Documents\\Machine Learning\\EDA\\bank.csv")

# %%
df2.head(20)
# Out:
#     age          job   marital  education default  balance housing loan  \
# 0    59       admin.   married  secondary      no     2343     yes   no
# 1    56       admin.   married  secondary      no       45      no   no
# 2    41   technician   married  secondary      no     1270     yes   no
# 3    55     services   married  secondary      no     2476     yes   no
# 4    54       admin.   married   tertiary      no      184      no   no
# 5    42   management    single   tertiary      no        0     yes  yes
# 6    56   management   married   tertiary      no      830     yes  yes
# 7    60      retired  divorced  secondary      no      545     yes   no
# 8    37   technician   married  secondary      no        1     yes   no
# 9    28     services    single  secondary      no     5090     yes   no
# 10   38       admin.    single  secondary      no      100     yes   no
# 11   30  blue-collar   married  secondary      no      309     yes   no
# ...

# %%
df2.groupby('education')

# %%
edu = df2.groupby('education')

# %%
edu

# %%
print(len(df2))
len(edu)
# Out:
# 11162
# 4

# %%
edu.size()
# Out:
# education
# primary      1500
# secondary    5476
# tertiary     3689
# unknown       497
# dtype: int64

# %%
edu.size().sort_values(ascending=False)
# Out:
# education
# secondary    5476
# tertiary     3689
# primary      1500
# unknown       497
# dtype: int64

# %%
edu.first()
# return first occurence of every group
# Out:
#            age          job  marital default  balance housing loan  contact  \
# education
# primary     32  blue-collar   single      no      611     yes   no  unknown
# secondary   59       admin.  married      no     2343     yes   no  unknown
# tertiary    54       admin.  married      no      184      no   no  unknown
# unknown     52   management  married      no     2240     yes   no  unknown
#
#            day month  duration  campaign  pdays  previous poutcome deposit
# education
# primary      8   may       541         3     -1         0  unknown     yes
# secondary    5   may      1042         1     -1         0  unknown     yes
# tertiary     5   may       673         2     -1         0  unknown     yes
# unknown     13   may       845         1     -1         0  unknown     yes

# %%
edu.last()
# return last occurence of every group
# Out:
#            age          job  marital default  balance housing loan   contact  \
# education
# primary     33  blue-collar   single      no        1     yes   no  cellular
# secondary   34   technician  married      no        0      no   no  cellular
# tertiary    52   technician  married      no      523     yes  yes  cellular
# unknown     49      retired  married      no      247      no   no   unknown
#
#            day month  duration  campaign  pdays  previous poutcome deposit
# education
# primary     20   apr       257         1     -1         0  unknown      no
# secondary    9   jul       628         1     -1         0  unknown      no
# tertiary     8   jul       113         1     -1         0  unknown      no
# unknown     15   may       213         2     -1         0  unknown      no

# %%
edu.groups
# returns index id of every row by groups
# Out:
# {'primary': [16, 23, 31, 34, 36, 39, 40, 45, 48, 49, 50, 57, 63, 64, 66, 67, 68, 70, 72, 73, 88, 101, 107, 109, 110, 116, 119, 125, 128, 132, 149, 172, 176, 183, 192, 196, 199, 202, 203, 211, 221, 223, 229, 235, 238, 246, 248, 252, 261, 269, 270, 278, 295, 311, 317, 322, 326, 329, 331, 334, 353, 355, 359, 366, 371, 381, 401, 402, 403, 411, 413, 414, 428, 431, 453, 454, 459, 469, 473, 482, 490, 493, 494, 499, 504, 505, 523, 525, 531, 561, 570, 578, 579, 583, 586, 588, 590, 591, 600, 611, ...], 'secondary': [0, 1, 2, 3, 7, 8, 9, 10, 11, 17, 18, 19, 20, 24, 25, 27, 28, 29, 30, 32, 33, 37, 43, 46, 47, 52, 53, 54, 55, 56, 60, 61, 62, 74, 78, 79, 80, 81, 82, 83, 84, 87, 89, 90, 91, 92, 93, 94, 97, 98, 99, 100, 102, 103, 104, 105, 106, 111, 112, 114, 115, 118, 122, 123, 124, 127, 129, 130, 133, 135, 136, 137, 139, 140, 142, 143, 145, 146, 147, 148, 150, 151, 152, 153, 156, 157, 158, 159, 160, 162, 164, 165, 166, 167, 168, 169, 171, 173, 175, 178, ...], 'tertiary': [4, 5, 6, 12, 13, 14, 15, 
# ...

# %%
df2.iloc[16, :]
# Out:
# age                   32
# job          blue-collar
# marital           single
# education        primary
# default               no
# balance              611
# housing              yes
# loan                  no
# contact          unknown
# day                    8
# month                may
# duration             541
# campaign               3
# pdays                 -1
# previous               0
# poutcome         unknown
# deposit              yes
# Name: 16, dtype: object

# %%
edu.get_group('primary')
# getting only primary group data
# returns dataframe, education column skipped
# Out:
#        age          job   marital education default  balance housing loan  \
# 16      32  blue-collar    single   primary      no      611     yes   no
# 23      43  blue-collar   married   primary      no     -192     yes   no
# 31      60   technician   married   primary      no       65     yes   no
# 34      33  blue-collar  divorced   primary      no      390     yes   no
# 36      35  blue-collar   married   primary      no      414      no   no
# ...    ...          ...       ...       ...     ...      ...     ...  ...
# 11115   49  blue-collar   married   primary      no       67      no  yes
# 11124   42      retired   married   primary      no        0     yes   no
# 11125   40  blue-collar  divorced   primary      no       54     yes   no
# 11128   40  blue-collar   married   primary      no     2171     yes   no
# 11157   33  blue-collar    single   primary      no        1     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
edu.sum()
# total sum of every group on numerical columns
# min,median,max,count...and more
# Out:
#               age  balance    day  duration  campaign   pdays  previous
# education
# primary     72331  2284547  23266    575705      3969   59965      1032
# secondary  219511  7099526  85255   2044437     13526  291882      4500
# tertiary   145764  6809411  58222   1359868      9176  195962      3410
# unknown     22625   868063   8032    172185      1328   25141       351

# %%
edu['balance'].mean().sort_values(ascending=False)
# Out:
# education
# tertiary     1845.869070
# unknown      1746.605634
# primary      1523.031333
# secondary    1296.480278
# Name: balance, dtype: float64

# %%
jobs = df2.groupby('job')

# %%
jobs.get_group('technician').shape
# Out:
# (1823, 17)

# %%
jobs['balance'].sum().sort_values(ascending=False)
# Out:
# job
# management       4602541
# technician       2837125
# blue-collar      2340433
# retired          1880621
# admin.           1595286
# services          997921
# self-employed     755476
# student           540282
# entrepreneur      531997
# unemployed        469355
# housemaid         374328
# unknown           136182
# Name: balance, dtype: int64

# %% [markdown]
# - top  batsman by runs
# ![image.png](attachment:image.png)

# %%
mask = df2['campaign']==2

# %%
new = df2[mask]

# %%
new.shape
# Out:
# (3028, 17)

# %%
# top 5 job which campaign =2 
new.groupby('job')['campaign'].count().sort_values(ascending=False).head(5)
# new.groupby('job')['campaign'].size().sort_values(ascending=False).head(5)
# Out:
# job
# management     718
# blue-collar    555
# technician     529
# admin.         326
# services       261
# Name: campaign, dtype: int64

# %% [markdown]
# # ISIN Funcation

# %%
ipl =  pd.read_csv('deliveries.csv')

# %%
ipl.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# ### Query?
# - find the most destructive death over batsman in the history of the IPL.
# - must played minimum batsman 200 balls in 16-20 overs
# - Strike rate = (number of runs/number of ball played)/100

# %%
# ipl

# %%
death_over=ipl[ipl['over']>15]

# %%
all_batsman = death_over.groupby('batsman')['batsman_runs'].count()

# %%
x = all_batsman>200

# %%
batsman_list=all_batsman[x].index.tolist()

# %%
final = ipl[ipl['batsman'].isin(batsman_list)]

# %%
runs = final.groupby('batsman')['batsman_runs'].sum()

# %%
balls = final.groupby('batsman')['batsman_runs'].count()

# %%
sr = (runs/balls)*100

# %%
sr
# Out:
# batsman
# A Mishra             89.005236
# AB de Villiers      145.129059
# AD Mathews          120.868114
# AM Rahane           117.486549
# AR Patel            122.672065
# AT Rayudu           123.014257
# BJ Hodge            121.422376
# DA Miller           137.709251
# DA Warner           138.318401
# DJ Bravo            122.286822
# DJ Hussey           120.072661
# DPMD Jayawardene    118.791064
# Harbhajan Singh     135.194585
# IK Pathan           116.751269
# JA Morkel           136.938202
# JH Kallis           105.936272
# JP Duminy           121.970624
# JP Faulkner         129.802956
# KA Pollard          140.621266
# KD Karthik          123.008475
# KM Jadhav           130.555556
# LRPL Taylor         120.070838
# MK Pandey           116.938453
# MK Tiwary           114.127424
# MS Dhoni            132.835821
# NV Ojha             114.528024
# P Kumar             105.263158
# PP Chawla           110.278373
# R Vinay Kumar       106.666667
# RA Jadeja           118.792867
# ...

# %% [markdown]
# # Merge
# - merge two dataframe (or two datafile)
# - same like join in SQL

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# - multi series
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Pivot table
# - more and quick readablity to data

# %%
df2.pivot_table(index=['job'],columns='education',values='balance',aggfunc='sum')
# Out:
# education      primary  secondary  tertiary  unknown
# job
# admin.           32589    1283319    225705    53673
# blue-collar     905508    1244251     83043   107631
# entrepreneur     53903     189100    275905    13089
# housemaid       196768      77913     88974    10673
# management      130227     322160   3980211   169943
# retired         616061     857249    328241    79070
# self-employed    35138     183863    518431    18044
# services        114756     730016     67827    85322
# student          31333     252034    167554    89361
# technician       74045    1691124    920196   151760
# unemployed       90014     243970    130424     4947
# unknown           4205      24527     22900    84550

# %%
df2.pivot_table(index=['job','default'],columns=['education','loan'],values='balance',aggfunc='sum')
# Out:
# education               primary           secondary             tertiary  \
# loan                         no      yes         no       yes         no
# job           default
# admin.        no        27208.0   5381.0  1147526.0  134529.0   216134.0
#               yes           NaN      NaN     1271.0      -7.0        NaN
# blue-collar   no       836938.0  71659.0  1090554.0  155067.0    81668.0
#               yes        -983.0  -2106.0    -1726.0     356.0        NaN
# entrepreneur  no        23862.0  30041.0   164833.0   24792.0   208950.0
#               yes           NaN      NaN        NaN    -525.0    -1032.0
# housemaid     no       188426.0   7353.0    69352.0   10027.0    88965.0
#               yes        1961.0   -972.0    -1531.0      65.0        NaN
# management    no       124577.0   5435.0   282507.0   33524.0  3747101.0
#               yes          13.0    202.0     6129.0       NaN     1092.0
# ...

# %%
mask = ipl['batsman_runs']==6
six = ipl[mask]
six.shape
# Out:
# (6523, 21)

# %%
six.pivot_table(index='over',columns='batting_team',values='batsman_runs',aggfunc='count')
# Out:
# batting_team  Chennai Super Kings  Deccan Chargers  Delhi Daredevils  \
# over
# 1                             5.0              3.0              14.0
# 2                            17.0             21.0              19.0
# 3                            37.0             11.0              30.0
# 4                            34.0             17.0              41.0
# 5                            41.0             27.0              29.0
# 6                            43.0             22.0              27.0
# 7                            22.0             11.0              20.0
# 8                            25.0             13.0              26.0
# 9                            23.0             17.0              32.0
# 10                           23.0             14.0              24.0
# 11                           36.0             15.0              34.0
# 12                           36.0             26.0              38.0
# ...

# %%
import seaborn as sns
sns.heatmap(six.pivot_table(index='over',columns='batting_team',values='batsman_runs',aggfunc='count'))
# Out:
# <AxesSubplot:xlabel='batting_team', ylabel='over'>

# %%
match = pd.read_csv('matches.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5536/2784625751.py in <module>
# ----> 1 match = pd.read_csv('matches.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
match.head()

# %%
match.corr()

# %%
sns.heatmap(match.corr())

# %% [markdown]
# # Rename function

# %%
match.rename(columns={'city':'place'}).head(2)

# %% [markdown]
# # set_index() vs reset_index()

# %% [markdown]
# ![image.png](attachment:image.png)
# - opposite of set_index
# ![image-2.png](attachment:image-2.png)
# - it converts series to dataframe
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # dropna()

# %% [markdown]
# - how = 'all', delete row/columns if all respective field nan(one row completly nan or one column completly nan)
# -how : {'any', 'all'}, default 'any'
#     Determine if row or column is removed from DataFrame, when we have
#     at least one NA or all NA.
#
#     * 'any' : If any NA values are present, drop that row or column.
#     * 'all' : If all values are NA, drop that row or column.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # fillna()
# -method : {'backfill', 'bfill', 'pad', 'ffill', None}, default None
#     Method to use for filling holes in reindexed Series
#     pad / ffill: propagate last valid observation forward to next valid
#     backfill / bfill: use next valid observation to fill gap.

# %%
# data.fillna(0) 
# fill data missing/nan values with 0 in eintire dataframa
# data['col1'].fillna(0) # only col1

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
# - bfill: back value replace
# ![image-4.png](attachment:image-4.png)

# %%
#Code #3: Using zip() for zipping two lists

# import pandas as pd
import pandas as pd
  
# list of strings
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks']
  
# list of int
lst2 = [11, 22, 33, 44, 55, 66, 77]
  
# Calling DataFrame constructor after zipping
# both lists, with columns specified
df = pd.DataFrame(list(zip(lst, lst2)),
               columns =['Name', 'val'])
df

# %%
#Code #4: Creating DataFrame using multi-dimensional list

# import pandas as pd
import pandas as pd 
    
# List1 
lst = [['tom', 25], ['krish', 30],
       ['nick', 26], ['juli', 22]]
    
df = pd.DataFrame(lst, columns =['Name', 'Age'])
df

# %%
# extracting data using two column conditions
df[(df['ssd'] != '0 GB') & (df['hdd'] != '0 GB')]

# %%
#extracting only null values rows in specific column

df[df['first_set'].isna()]

# df[df['first_set']==np.nan]....this is not work

# %%
# importing the module
import pandas as pd
  
# creating 2 DataFrames
location = pd.DataFrame({'area': ['new-york', 'columbo', 'mumbai']})
food = pd.DataFrame({'food': ['pizza', 'crabs', 'vada-paw']})
  
# concatenating the DataFrames
det = pd.concat([location, food], join = 'outer', axis = 1)
  
# displaying the DataFrame
print(det)
# Out:
#        area      food
# 0  new-york     pizza
# 1   columbo     crabs
# 2    mumbai  vada-paw

# %%
# importing the module
import pandas as pd
  
# creating 2 DataFrames
first = pd.DataFrame([['one', 1], ['three', 3]], columns =['name', 'word'])
second = pd.DataFrame([['two', 2], ['four', 4]], columns =['name', 'word'])
  
# concatenating the DataFrames
dt = first.append(second, ignore_index = True)
  
# displaying the DataFrame
print(dt)

# %%
# Example 3 : Using the .join() method./

# importing the module
import pandas as pd
  
# creating 2 DataFrames
location = pd.DataFrame({'area' : ['new-york', 'columbo', 'mumbai']})
food = pd.DataFrame({'food': ['pizza', 'crabs', 'vada-paw']})
  
# concatenating the DataFrames
dt = location.join(food)
  
# displaying the DataFrame
print(dt)
# Out:
#        area      food
# 0  new-york     pizza
# 1   columbo     crabs
# 2    mumbai  vada-paw

# %% [markdown]
# Load datasets online

# %%
import seaborn as sns
df = sns.load_dataset('titanic')
df.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
import plotly.express as px
df = px.data.iris()
df.sample().style.background_gradient(cmap='cool')
# Out:
# <style type="text/css">
# #T_dbeac_row0_col0, #T_dbeac_row0_col1, #T_dbeac_row0_col2, #T_dbeac_row0_col3, #T_dbeac_row0_col5 {
#   background-color: #00ffff;
#   color: #000000;
# }
# </style>
# <table id="T_dbeac_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >sepal_length</th>
#       <th class="col_heading level0 col1" >sepal_width</th>
#       <th class="col_heading level0 col2" >petal_length</th>
#       <th class="col_heading level0 col3" >petal_width</th>
#       <th class="col_heading level0 col4" >species</th>
#       <th class="col_heading level0 col5" >species_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbeac_level0_row0" class="row_heading level0 row0" >55</th>
#       <td id="T_dbeac_row0_col0" class="data row0 col0" >5.700000</td>
#       <td id="T_dbeac_row0_col1" class="data row0 col1" >2.800000</td>
# ...

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.io.formats.style.Styler.background_gradient.html

# %%
from sklearn.datasets import load_iris
df = load_iris()

# %%
df.head().style.background_gradient(cmap='cool')

# %% [markdown]
# ![image.png](attachment:image.png)
